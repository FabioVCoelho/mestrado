# %%
import os
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', 200)
pd.set_option('display.width', 120)

# Diretório dos dados (ajustado para o projeto atual)
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
data_dir = os.path.join(project_root, 'data')
data_dir
# Out:
# 'C:\\Users\\User\\PycharmProjects\\mestrado\\Machine Learning\\Project_1\\data'

# %%
path = "../data/umidades sensores solo.xlsx"
pd.read_excel(path, engine='openpyxl')
# Out:
#                      DATA  Umidade Arado 0-30cm (m³/m³)  Lâmina de água (mm)  DTA (mm/m)  CTA (mm)  CRA (mm)  \
# 0     2023-12-15 15:00:00                      0.325376             97.61271       100.0      30.0      16.5
# 1     2023-12-15 16:00:00                      0.323387             97.01613       100.0      30.0      16.5
# 2     2023-12-15 17:00:00                      0.322393             96.71784       100.0      30.0      16.5
# 3     2023-12-15 18:00:00                      0.321398             96.41955       100.0      30.0      16.5
# 4     2023-12-15 19:00:00                      0.321398             96.41955       100.0      30.0      16.5
# ...                   ...                           ...                  ...         ...       ...       ...
# 15761 2025-10-02 09:00:00                      0.139442             41.83248       100.0      30.0      16.5
# 15762 2025-10-02 10:00:00                      0.139442             41.83248       100.0      30.0      16.5
# 15763 2025-10-02 11:00:00                      0.140436             42.13077       100.0      30.0      16.5
# 15764 2025-10-02 12:00:00                      0.140436             42.13077       100.0      30.0      16.5
# 15765 2025-10-02 13:00:00                      0.141430             42.42906       100.0      30.0      16.5
#
#        Umidade Arado 30-60cm (m³/m³)  Lâmina de água (mm).1  DTA (mm/m).1  CTA (mm).1  CRA (mm).1  \
# 0                           0.340350              102.10506         100.0        30.0        16.5
# 1                           0.340350              102.10506         100.0        30.0        16.5
# 2                           0.340350              102.10506         100.0        30.0        16.5
# 3                           0.339186              101.75565         100.0        30.0        16.5
# 4                           0.339186              101.75565         100.0        30.0        16.5
# ...                              ...                    ...           ...         ...         ...
# 15761                       0.184280               55.28412         100.0        30.0        16.5
# 15762                       0.184280               55.28412         100.0        30.0        16.5
# 15763                       0.184280               55.28412         100.0        30.0        16.5
# 15764                       0.184280               55.28412         100.0        30.0        16.5
# 15765                       0.184280               55.28412         100.0        30.0        16.5
#
#        Lâmina de água LA (mm) 0-60cm  CTA 0-60cm (mm)  CRA 0-60cm (mm)  Lâmina crítica LC (mm)    LA - LC  \
# 0                          199.71777             60.0             33.0                     207   -7.28223
# 1                          199.12119             60.0             33.0                     207   -7.87881
# 2                          198.82290             60.0             33.0                     207   -8.17710
# 3                          198.17520             60.0             33.0                     207   -8.82480
# 4                          198.17520             60.0             33.0                     207   -8.82480
# ...                              ...              ...              ...                     ...        ...
# 15761                       97.11660             60.0             33.0                     207 -109.88340
# 15762                       97.11660             60.0             33.0                     207 -109.88340
# 15763                       97.41489             60.0             33.0                     207 -109.58511
# 15764                       97.41489             60.0             33.0                     207 -109.58511
# 15765                       97.71318             60.0             33.0                     207 -109.28682
#
#       (LA-LC)<0 = estresse; (LA-LC)>0 = sem estresse  Umidade Plantio Direto 0-30cm (m³/m³)  Lâmina de água (mm).2  \
# 0                                           ESTRESSE                               0.333424              100.02723
# 1                                           ESTRESSE                               0.333424              100.02723
# 2                                           ESTRESSE                               0.332578               99.77346
# 3                                           ESTRESSE                               0.331732               99.51969
# 4                                           ESTRESSE                               0.330886               99.26592
# ...                                              ...                                    ...                    ...
# 15761                                       ESTRESSE                               0.189621               56.88633
# 15762                                       ESTRESSE                               0.189621               56.88633
# 15763                                       ESTRESSE                               0.190467               57.14010
# 15764                                       ESTRESSE                               0.190467               57.14010
# 15765                                       ESTRESSE                               0.190467               57.14010
#
#        DTA (mm/m).2  CTA (mm).2  CRA (mm).2  Umidade Plantio Direto 30-60cm (m³/m³)  Lâmina de água (mm).3  \
# 0             100.0        30.0        16.5                                0.369522              110.85657
# 1             100.0        30.0        16.5                                0.368508              110.55228
# 2             100.0        30.0        16.5                                0.368508              110.55228
# 3             100.0        30.0        16.5                                0.368508              110.55228
# 4             100.0        30.0        16.5                                0.368508              110.55228
# ...             ...         ...         ...                                     ...                    ...
# 15761         100.0        30.0        16.5                                0.198105               59.43156
# 15762         100.0        30.0        16.5                                0.198105               59.43156
# 15763         100.0        30.0        16.5                                0.198105               59.43156
# 15764         100.0        30.0        16.5                                0.198105               59.43156
# 15765         100.0        30.0        16.5                                0.198105               59.43156
#
#        DTA (mm/m).3  CTA (mm).3  CRA (mm).3  Lâmina de água LA (mm) 0-60cm.1  CTA 0-60cm (mm).1  CRA 0-60cm (mm).1  \
# 0             100.0        30.0        16.5                        210.88380               60.0               33.0
# 1             100.0        30.0        16.5                        210.57951               60.0               33.0
# 2             100.0        30.0        16.5                        210.32574               60.0               33.0
# 3             100.0        30.0        16.5                        210.07197               60.0               33.0
# 4             100.0        30.0        16.5                        209.81820               60.0               33.0
# ...             ...         ...         ...                              ...                ...                ...
# 15761         100.0        30.0        16.5                        116.31789               60.0               33.0
# 15762         100.0        30.0        16.5                        116.31789               60.0               33.0
# 15763         100.0        30.0        16.5                        116.57166               60.0               33.0
# 15764         100.0        30.0        16.5                        116.57166               60.0               33.0
# 15765         100.0        30.0        16.5                        116.57166               60.0               33.0
#
#        Lâmina crítica LC (mm).1  LA - LC.1 (LA-LC)<0 = estresse; (LA-LC)>0 = sem estresse.1  Unnamed: 33  \
# 0                           207    3.88380                                     SEM ESTRESSE          NaN
# 1                           207    3.57951                                     SEM ESTRESSE          NaN
# 2                           207    3.32574                                     SEM ESTRESSE          NaN
# 3                           207    3.07197                                     SEM ESTRESSE          NaN
# 4                           207    2.81820                                     SEM ESTRESSE          NaN
# ...                         ...        ...                                              ...          ...
# 15761                       207  -90.68211                                         ESTRESSE          NaN
# 15762                       207  -90.68211                                         ESTRESSE          NaN
# 15763                       207  -90.42834                                         ESTRESSE          NaN
# 15764                       207  -90.42834                                         ESTRESSE          NaN
# 15765                       207  -90.42834                                         ESTRESSE          NaN
#
#          CC (m³/m³)    PMP (m³/m³)
# 0               0.4            0.3
# 1      CC (mm) 60cm  PMP (mm) 60cm
# 2               240            180
# 3               NaN            NaN
# 4               NaN            NaN
# ...             ...            ...
# 15761           NaN            NaN
# 15762           NaN            NaN
# 15763           NaN            NaN
# 15764           NaN            NaN
# 15765           NaN            NaN
#
# [15766 rows x 36 columns]
